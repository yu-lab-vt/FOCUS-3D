# %%
# test.ipynb
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
from train_net_3d import build_cfg, run_train

config_file = './configs/3d_test.yaml'
cfg = build_cfg(config_file, [])
run_train(cfg, resume=True)  # resume from checkpoint, set True
# Out:
# [05/22 21:37:25 detectron2]: Rank of current process: 0. World size: 1
# [05/22 21:37:26 detectron2]: Environment info:
# -------------------------------  ---------------------------------------------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.19 (main, Oct 21 2025, 16:43:05) [GCC 11.2.0]
# numpy                            2.2.6
# detectron2                       0.6 @/home/zqh/detectron2/detectron2
# Compiler                         GCC 11.4
# CUDA compiler                    CUDA 12.4
# detectron2 arch flags            /home/zqh/detectron2/detectron2/_C.cpython-310-x86_64-linux-gnu.so; cannot find cuobjdump
# DETECTRON2_ENV_MODULE            <not set>
# PyTorch                          2.5.1+cu121 @/home/zqh/.conda/envs/cellseg/lib/python3.10/site-packages/torch
# PyTorch debug build              False
# torch._C._GLIBCXX_USE_CXX11_ABI  False
# GPU available                    Yes
# ...
